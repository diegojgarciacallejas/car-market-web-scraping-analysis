# %%
import pandas as pd

# %%
#Leemos los csv
coches_francia_df= pd.read_csv('../data/processed/cars_france.csv', index_col= 0)
coches_holanda_df= pd.read_csv('../data/processed/cars_netherlands.csv', index_col= 0)
coches_alemania_df= pd.read_csv('../data/processed/cars_germany.csv', index_col= 0)
coches_españa_df= pd.read_csv('../data/processed/cars_spain.csv' ,index_col= 0)

# %%
#Cogemos los coches de holanda por separado
df_renault_holanda= coches_holanda_df.loc['RENAULT']
df_seat_holanda= coches_holanda_df.loc['SEAT']
df_opel_holanda= coches_holanda_df.loc['OPEL']
df_hyundai_holanda= coches_holanda_df.loc['HYUNDAI']
df_toyota_holanda= coches_holanda_df.loc['TOYOTA']
df_volkswagen_holanda= coches_holanda_df.loc['VOLKSWAGEN']

# %%
#Quitamos datos iguales oara que la grafica quedebe bien
df_visualitation_holanda_renault= df_renault_holanda[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_holanda_seat= df_seat_holanda[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_holanda_opel= df_opel_holanda[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_holanda_hyundai= df_hyundai_holanda[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_holanda_toyota= df_toyota_holanda[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_holanda_volkswagen= df_volkswagen_holanda[['kilometros', 'precio']].drop_duplicates(keep= 'first')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(18,9))
ax1= plt.subplot(1,2,1)

sns.regplot(x='kilometros', y='precio', data=df_visualitation_holanda_renault, scatter_kws={'alpha': 0.5, 'color': 'red'}, line_kws={'color': 'red'}, ax= ax1, label= 'RENAULT', ci= None)
sns.regplot(x='kilometros', y='precio', data=df_visualitation_holanda_seat, scatter_kws={'alpha': 0.5, 'color': 'blue'}, line_kws={'color': 'blue'}, ax= ax1, label= 'SEAT', ci= None)
sns.regplot(x='kilometros', y='precio', data=df_visualitation_holanda_opel, scatter_kws={'alpha': 0.5, 'color': 'green'}, line_kws={'color': 'green'}, ax= ax1, label='OPEL', ci= None)

plt.legend()
plt.xlabel('Kilómetros', fontsize=12)
plt.ylabel('Precio', fontsize=12)

ax2= plt.subplot(1,2,2)

sns.regplot(x='kilometros', y='precio', data=df_visualitation_holanda_hyundai, scatter_kws={'alpha': 0.5, 'color': 'purple'}, line_kws={'color': 'purple'}, ax= ax2, label= 'HYUNDAI')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_holanda_toyota, scatter_kws={'alpha': 0.5, 'color': 'orange'}, line_kws={'color': 'orange'}, ax= ax2, label= 'TOYOTA')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_holanda_volkswagen, scatter_kws={'alpha': 0.5, 'color': 'black'}, line_kws={'color': 'black'}, ax= ax2, label='VOLKSWAGEN')

plt.legend()
plt.xlabel('Kilómetros', fontsize=12)
plt.ylabel('Precio', fontsize=12)

plt.suptitle('Relación entre Kilómetros y Precio de Coches-Holanda', fontsize=14)
plt.show()

# %%
#Cogemos los coches de francia por separado
df_volkswagen_francia= coches_francia_df.loc['VOLKSWAGEN']
df_toyota_francia= coches_francia_df.loc['TOYOTA']
df_hyundai_francia= coches_francia_df.loc['HYUNDAI']
df_opel_francia= coches_francia_df.loc['OPEL']
df_seat_francia= coches_francia_df.loc['SEAT']
df_renault_francia= coches_francia_df.loc['RENAULT']

# %%
#Eliminamos datos iguales para que las graficas quedeb bien 
df_visualitation_francia_renault= df_renault_francia[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_francia_seat= df_seat_francia[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_francia_opel= df_opel_francia[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_francia_hyundai= df_hyundai_francia[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_francia_toyota= df_toyota_francia[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_francia_volkswagen= df_volkswagen_francia[['kilometros', 'precio']].drop_duplicates(keep= 'first')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18,9))
ax3= plt.subplot(1,2,1)

sns.regplot(x='kilometros', y='precio', data=df_visualitation_francia_renault, scatter_kws={'alpha': 0.5, 'color': 'red'}, line_kws={'color': 'red'}, ax= ax3, label= 'RENAULT')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_francia_seat, scatter_kws={'alpha': 0.5, 'color': 'blue'}, line_kws={'color': 'blue'}, ax= ax3, label= 'SEAT')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_francia_opel, scatter_kws={'alpha': 0.5, 'color': 'green'}, line_kws={'color': 'green'}, ax= ax3, label='OPEL')

plt.legend()
plt.xlabel('Kilómetros', fontsize=12)
plt.ylabel('Precio', fontsize=12)

ax4= plt.subplot(1,2,2)

sns.regplot(x='kilometros', y='precio', data=df_visualitation_francia_hyundai, scatter_kws={'alpha': 0.5, 'color': 'purple'}, line_kws={'color': 'purple'}, ax= ax4, label= 'HYUNDAI')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_francia_toyota, scatter_kws={'alpha': 0.5, 'color': 'orange'}, line_kws={'color': 'orange'}, ax= ax4, label= 'TOYOTA')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_francia_volkswagen, scatter_kws={'alpha': 0.5, 'color': 'black'}, line_kws={'color': 'black'}, ax= ax4, label='VOLKSWAGEN')

plt.legend()
plt.xlabel('Kilómetros', fontsize=12)
plt.ylabel('Precio', fontsize=12)

plt.suptitle('Relación entre Kilómetros y Precio de Coches-Francia', fontsize=14)
# Out:
# Text(0.5, 0.98, 'Relación entre Kilómetros y Precio de Coches-Francia')

# %%
#Cogemos los coches de alemania por separado
df_renault_alemania= coches_alemania_df.loc['RENAULT']
df_seat_alemania= coches_alemania_df.loc['SEAT']
df_opel_alemania= coches_alemania_df.loc['OPEL']
df_hyundai_alemania= coches_alemania_df.loc['HYUNDAI']
df_toyota_alemania= coches_alemania_df.loc['TOYOTA']
df_volkswagen_alemania= coches_alemania_df.loc['VOLKSWAGEN']

# %%
df_visualitation_alemania_renault = df_renault_alemania[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_alemania_seat =df_seat_alemania[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_alemania_opel = df_opel_alemania[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_alemania_hyundai =df_hyundai_alemania[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_alemania_toyota = df_toyota_alemania[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_alemania_volkswagen = df_volkswagen_alemania[['kilometros', 'precio']].drop_duplicates(keep= 'first')

# %%
plt.figure(figsize=(18,9))
ax1= plt.subplot(1,2,1)

sns.regplot(x='kilometros', y='precio', data=df_visualitation_alemania_renault, scatter_kws={'alpha': 0.5, 'color': 'red'}, line_kws={'color': 'red'},ax= ax1, label= 'RENAULT')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_alemania_hyundai, scatter_kws={'alpha': 0.5, 'color': 'purple'}, line_kws={'color': 'purple'}, ax= ax1, label= 'HYUNDAI')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_alemania_volkswagen, scatter_kws={'alpha': 0.5, 'color': 'black'}, line_kws={'color': 'black'}, ax= ax1, label='VOLSKSWAGEN')


plt.legend()
plt.xlabel('Kilómetros', fontsize=12)
plt.ylabel('Precio', fontsize=12)

ax2= plt.subplot(1,2,2)

sns.regplot(x='kilometros', y='precio', data=df_visualitation_alemania_toyota, scatter_kws={'alpha': 0.5, 'color': 'orange'}, line_kws={'color': 'orange'},  ax= ax2, label= 'TOYOTA')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_alemania_seat, scatter_kws={'alpha': 0.5, 'color': 'blue'}, line_kws={'color': 'blue'},  ax= ax2, label= 'SEAT')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_alemania_opel, scatter_kws={'alpha': 0.5, 'color': 'green'}, line_kws={'color': 'green'},  ax= ax2, label='OPEL')

plt.legend()
plt.xlabel('Kilómetros', fontsize=12)
plt.ylabel('Precio', fontsize=12)

plt.suptitle('Relación entre Kilómetros y Precio de Coches en Alemania', fontsize=14)
plt.show()

# %%
#Cogemos los coches de españa por separado
df_renault_españa= coches_españa_df.loc['RENAULT']
df_seat_españa= coches_españa_df.loc['SEAT']
df_opel_españa= coches_españa_df.loc['OPEL']
df_hyundai_españa= coches_españa_df.loc['HYUNDAI']
df_toyota_españa= coches_españa_df.loc['TOYOTA']
df_volkswagen_españa= coches_españa_df.loc['VOLKSWAGEN']

# %%
df_visualitation_españa_renault =  df_renault_españa[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_españa_seat =  df_seat_españa[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_españa_opel =  df_opel_españa[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_españa_hyundai = df_hyundai_españa[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_españa_toyota =  df_toyota_españa[['kilometros', 'precio']].drop_duplicates(keep= 'first')
df_visualitation_españa_volkswagen =  df_volkswagen_españa[['kilometros', 'precio']].drop_duplicates(keep= 'first')

# %%
plt.figure(figsize=(18,9))
ax1= plt.subplot(1,2,1)

sns.regplot(x='kilometros', y='precio', data=df_visualitation_españa_renault, scatter_kws={'alpha': 0.5, 'color': 'red'}, line_kws={'color': 'red'}, ax= ax1, label= 'RENAULT')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_españa_hyundai, scatter_kws={'alpha': 0.5, 'color': 'purple'}, line_kws={'color': 'purple'}, ax= ax1, label= 'HYUNDAI')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_españa_volkswagen, scatter_kws={'alpha': 0.5, 'color': 'black'}, line_kws={'color': 'black'}, ax= ax1, label='VOLSKSWAGEN')



plt.legend()
plt.xlabel('Kilómetros', fontsize=12)
plt.ylabel('Precio', fontsize=12)

ax2= plt.subplot(1,2,2)

sns.regplot(x='kilometros', y='precio', data=df_visualitation_españa_toyota, scatter_kws={'alpha': 0.5, 'color': 'orange'}, line_kws={'color': 'orange'}, ax= ax2, label= 'TOYOTA')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_españa_seat, scatter_kws={'alpha': 0.5, 'color': 'blue'}, line_kws={'color': 'blue'}, ax= ax2, label= 'SEAT')
sns.regplot(x='kilometros', y='precio', data=df_visualitation_españa_opel, scatter_kws={'alpha': 0.5, 'color': 'green'}, line_kws={'color': 'green'}, ax= ax2, label='OPEL')

plt.legend()
plt.xlabel('Kilómetros', fontsize=12)
plt.ylabel('Precio', fontsize=12)

plt.suptitle('Relación entre Kilómetros y Precio de Coches en España', fontsize=14)
plt.show()
